# %% [markdown]
# # Unit 3 – Supervised Learning: Classification
#
# Use this notebook to explore classification metrics, class imbalance and decision thresholds.

# %% [markdown]
# ## 1. Setup and data loading
#
# Run the cell below to import libraries and load the sample dataset from `../data/unit3_classification_features.csv`.

# %%
import pandas as pd
from pathlib import Path

data_path = Path('..') / 'data' / 'unit3_classification_features.csv'
df = pd.read_csv(data_path)

df['is_high_risk'].value_counts(normalize=True)

# %% [markdown]
# ## 2. Baseline classifier and confusion matrix
#
# Fit a baseline classifier (e.g. logistic regression). Show the confusion matrix and compute accuracy, precision, recall and F1.

# %% [markdown]
# ## 3. Class imbalance and threshold tuning
#
# Use predicted probabilities to explore different decision thresholds and how they affect precision/recall.

# %% [markdown]
# ## 4. ROC and precision–recall curves
#
# Plot ROC and PR curves. Interpret what they mean for this problem.
