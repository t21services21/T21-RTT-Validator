# %% [markdown]
# # Unit 7 – Capstone Project Template
#
# Use this notebook as a structured template for your end-to-end Intermediate ML capstone project.

# %% [markdown]
# ## 1. Title & problem statement
#
# Describe the project title and the real-world question you are answering.

# %% [markdown]
# ## 2. Context & stakeholders
#
# Who cares about this problem? How will decisions change if your model works well?

# %% [markdown]
# ## 3. Data understanding & EDA
#
# Describe your data sources, key fields and basic exploratory analysis.

# %% [markdown]
# ## 4. Feature engineering & pipelines
#
# Design and implement your feature table and preprocessing pipeline.

# %% [markdown]
# ## 5. Modelling (baseline + improved)
#
# Train at least one baseline model and an improved model. Compare them using appropriate metrics.

# %% [markdown]
# ## 6. Evaluation & validation
#
# Explain your validation strategy and why your chosen metrics match the business question.

# %% [markdown]
# ## 7. (Optional) Segmentation / unsupervised analysis
#
# If useful, explore clustering or other unsupervised structure that supports your story.

# %% [markdown]
# ## 8. Deployment & monitoring plan
#
# Sketch how this model (or analysis) could be deployed and how you would monitor it over time.

# %% [markdown]
# ## 9. Conclusions, limitations, next steps
#
# Summarise what you learned, key limitations, and potential follow-up work.
