# %% [markdown]
# # Unit 4 – Model Evaluation & Validation
#
# Use this notebook to practise validation strategies and generalisation checks.

# %% [markdown]
# ## 1. Setup and data loading
#
# Reuse one of the datasets from Units 2 or 3 (regression or classification). Load it below.

# %%
import pandas as pd
from pathlib import Path

# Example: reuse regression features
data_path = Path('..') / 'data' / 'unit2_regression_features.csv'
df = pd.read_csv(data_path)
df.head()

# %% [markdown]
# ## 2. Train/validation/test split
#
# Create explicit train, validation and test sets. Compare metrics across them.

# %% [markdown]
# ## 3. k-fold cross-validation
#
# Use `cross_val_score` or similar to compute CV scores and compare them to the single validation split.

# %% [markdown]
# ## 4. Time-aware validation (optional)
#
# If your data has dates or an order, demonstrate a time-based split and explain why random shuffling may be wrong.

# %% [markdown]
# ## 5. What not to do with the test set
#
# Show a small example of tuning on the test set and why this leads to over-optimistic performance estimates.
