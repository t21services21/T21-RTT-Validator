# %% [markdown]
# # Unit 2 – Supervised Learning: Regression
#
# Use this notebook to practice building and evaluating regression models with regularisation.

# %% [markdown]
# ## 1. Setup and data loading
#
# Run the cell below to import libraries and load the sample dataset from `../data/unit2_regression_features.csv`.

# %%
import pandas as pd
from pathlib import Path

data_path = Path('..') / 'data' / 'unit2_regression_features.csv'
df = pd.read_csv(data_path)

df.head()

# %% [markdown]
# ## 2. Baseline linear regression
#
# Split into train/validation/test sets and fit a baseline `LinearRegression` model. Compute RMSE/MAE/R².

# %% [markdown]
# ## 3. Regularised models (Ridge & Lasso)
#
# Fit Ridge and Lasso models for several `alpha` values. Compare metrics to the baseline and inspect coefficients.

# %% [markdown]
# ## 4. Model comparison and interpretation
#
# Summarise how the different models perform and what the key features seem to be.
