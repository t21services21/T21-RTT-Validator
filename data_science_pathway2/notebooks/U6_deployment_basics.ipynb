# %% [markdown]
# # Unit 6 – Deploying & Operationalising Models
#
# Use this notebook to practise saving/loading pipelines and sketching simple deployment patterns.

# %% [markdown]
# ## 1. Load a trained pipeline
#
# Assume you have trained and saved a pipeline in Unit 1 or 2 as `../artifacts/u1_feature_pipeline.joblib` (or similar). Load it here.

# %% [markdown]
# ## 2. Batch scoring helper
#
# Implement a `score_file(input_path, output_path)` function that loads a CSV, applies the pipeline and writes predictions.

# %% [markdown]
# ## 3. CLI-style usage example
#
# Sketch how a command like `python score.py --in data.csv --out preds.csv` would work, even if the script is not created yet.

# %% [markdown]
# ## 4. Simple app or UI stub
#
# Outline how you would build a small Streamlit or CLI interface for entering features and getting predictions.

# %% [markdown]
# ## 5. Monitoring and feedback
#
# Add notes or example code for monitoring data ranges, performance metrics and potential drift over time.
