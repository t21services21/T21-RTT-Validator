# %% [markdown]
# # Unit 5 – Unsupervised Learning & Segmentation
#
# Use this notebook to experiment with clustering and basic segment profiling.

# %% [markdown]
# ## 1. Setup and data loading
#
# Run the cell below to import libraries and load the sample dataset from `../data/unit5_segmentation_features.csv`.

# %%
import pandas as pd
from pathlib import Path

data_path = Path('..') / 'data' / 'unit5_segmentation_features.csv'
df = pd.read_csv(data_path)
df.head()

# %% [markdown]
# ## 2. Preprocessing and scaling
#
# Select numeric features and scale them appropriately before clustering.

# %% [markdown]
# ## 3. k-means for several k values
#
# Fit k-means for k=2..6 (for example). Track inertia and silhouette scores.

# %% [markdown]
# ## 4. Cluster profiling and business interpretation
#
# Add cluster labels back to the original data. Compute per-cluster summaries and describe possible business labels for each segment.
