# %% [markdown]
# # Unit 7 – Advanced Production-style Capstone Template
#
# Structured template for your Pathway 3 capstone project.

# %% [markdown]
# ## 1. Problem & context
#
# Describe the problem, stakeholders, constraints and success criteria.

# %% [markdown]
# ## 2. Data & feature pipeline
#
# Document data sources and your feature engineering pipeline.

# %% [markdown]
# ## 3. Experiments & model choice
#
# Summarise experiments, tracking approach and chosen model.

# %% [markdown]
# ## 4. Packaging, deployment & monitoring plan
#
# Explain how the model would be deployed and monitored in production.

# %% [markdown]
# ## 5. Responsible AI, risks & limitations
#
# Discuss fairness, risk, limitations and mitigations.
