# %% [markdown]
# # Unit 4 – Time-series Forecasting for Operations
#
# Use this notebook to run forecasting experiments for operational questions.

# %%
import pandas as pd
from pathlib import Path

data_path = Path('..') / 'data' / 'p3_unit4_timeseries_daily.csv'
ts = pd.read_csv(data_path, parse_dates=['date']).set_index('date')
ts.head()

# %% [markdown]
# ## 1. Baseline forecasts
#
# Implement naïve and moving-average baselines.

# %% [markdown]
# ## 2. Simple forecasting model
#
# Add at least one simple model (e.g. ARIMA-style or tree-based on lag features).

# %% [markdown]
# ## 3. Rolling-origin evaluation
#
# Evaluate forecasts using a rolling-window/rolling-origin scheme.
