# %% [markdown]
# # Unit 5 – Packaging, Environments & CI/CD for ML
#
# Use this notebook to sketch environment specs and packaging ideas.

# %% [markdown]
# ## 1. Environment specification
#
# Draft a requirements.txt or similar and test building an environment.

# %% [markdown]
# ## 2. Batch scoring design
#
# Outline a simple batch scoring script and configuration parameters.

# %% [markdown]
# ## 3. CI/CD workflow sketch
#
# Describe tests and steps you would automate in CI/CD for this project.
