# %% [markdown]
# # Unit 1 – Advanced Feature Engineering & Pipelines at Scale
#
# This notebook is for designing and testing production-style feature pipelines.

# %% [markdown]
# ## 1. Load data and recap existing features
#
# Re-use or simulate a dataset from Pathway 2 to start this unit.

# %% [markdown]
# ## 2. Design a multi-model feature table
#
# Sketch columns, keys and timestamps for a feature table that could support several models.

# %% [markdown]
# ## 3. Implement a point-in-time safe feature pipeline
#
# Implement functions or pipelines that respect point-in-time correctness.

# %% [markdown]
# ## 4. Document feature definitions
#
# Record clear feature definitions, owners and refresh cadence.
