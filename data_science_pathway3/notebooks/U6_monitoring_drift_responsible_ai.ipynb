# %% [markdown]
# # Unit 6 – Monitoring, Drift & Responsible AI
#
# Use this notebook to design monitoring signals and fairness checks.

# %% [markdown]
# ## 1. Monitoring signals
#
# List and, where possible, simulate key data/performance metrics to monitor.

# %% [markdown]
# ## 2. Segment analysis
#
# Analyse metrics by subgroup (e.g. region, age band) for fairness insights.

# %% [markdown]
# ## 3. Incident scenarios
#
# Write and reason through a few incident scenarios and responses.
