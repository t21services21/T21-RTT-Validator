# %% [markdown]
# # Unit 3 – Advanced Supervised Models & Ensembles
#
# Use this notebook to benchmark baselines vs advanced models and explore calibration.

# %% [markdown]
# ## 1. Baselines vs advanced models
#
# Train simple baselines and at least one boosting model + one random forest.

# %% [markdown]
# ## 2. Cross-validation and metrics
#
# Evaluate models across multiple folds and compare metrics.

# %% [markdown]
# ## 3. Calibration and interpretability
#
# Explore calibration curves or binned analysis and inspect feature importances.
