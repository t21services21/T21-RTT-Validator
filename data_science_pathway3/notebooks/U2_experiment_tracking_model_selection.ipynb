# %% [markdown]
# # Unit 2 – Experiment Tracking & Model Selection
#
# Use this notebook to explore experiment logging and fair model comparison.

# %% [markdown]
# ## 1. Define an experiment log schema
#
# Decide which fields you will log for each run (params, data versions, metrics, artefacts).

# %% [markdown]
# ## 2. Implement a simple logging helper
#
# Create functions for writing/reading experiment records (e.g. to CSV/JSON).

# %% [markdown]
# ## 3. Run and log model families
#
# Train several model types on a chosen problem and log all runs.

# %% [markdown]
# ## 4. Analyse logged results
#
# Build comparison tables/plots from the experiment log.
