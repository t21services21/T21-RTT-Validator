# %% [markdown]
# # Unit 7 Lab: Capstone Project Template
#
# This notebook is a **structured template** for your Foundations capstone
# project. You will choose a dataset (for example from the `capstone_datasets`
# folder) and complete each section.
#
# Your goal is to produce a project that you can show to employers in the UK,
# US or anywhere else as proof of your practical skills.
#
# ---
#
# ## 1. Project overview
#
# Fill in the sections below.
#
# ```markdown
# ### 1.1 Title
#
# (Example: "Retail Sales Performance in UK Stores" or "US Credit Risk
# Analysis".)
#
# ### 1.2 Background
#
# Describe the business context in 3–5 sentences.
#
# ### 1.3 Objectives
#
# List 2–4 clear questions you want to answer.
# ```
#
# ---
#
# ## 2. Data description
#
# ```markdown
# ### 2.1 Dataset(s) used
#
# - File name(s): ...
# - Source: internal training dataset
#
# ### 2.2 Key fields
#
# List important columns and what each one represents.
# ```
#
# If you are using multiple datasets (e.g. customers + transactions), explain
# how they link together.
#
# ---
#
# ## 3. Data cleaning & preparation
#
# Use code cells to:
#
# - Load the data.
# - Fix obvious issues (missing values, types, duplicates).
# - Create any new features you need (for example, year/month, age bands,
#   spend categories).
#
# Add short comments explaining what you are doing and why.
#
# ---
#
# ## 4. Analysis & visualisation
#
# Use the skills from previous units:
#
# - Grouped summaries with `pandas`.
# - Charts with Matplotlib / Seaborn / Plotly.
#
# For each key question from your objectives, include:
#
# 1. The code and output (table or chart).
# 2. A short written interpretation (2–4 sentences).
#
# ---
#
# ## 5. Conclusions & recommendations
#
# ```markdown
# ### 5.1 Key findings
#
# Summarise the most important insights from your analysis.
#
# ### 5.2 Recommended actions
#
# List 2–3 practical actions a business could take based on your work.
#
# ### 5.3 Limitations & next steps
#
# Be honest about what you could not do with this data and what you would do
# next if you had more time or more data.
# ```
#
# ---
#
# ## 6. Reflection for your portfolio
#
# In a final Markdown cell, write a short reflection (5–8 sentences) on:
#
# - What you learned while doing this project.
# - Which skills (Python, Pandas, SQL, statistics, visualisation) you used.
# - How this project shows that you are ready for an entry-level data role in
#   your preferred country and sector.
